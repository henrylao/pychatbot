# %% [markdown]
# # Setup

# %% [markdown]
# ### Setup: Import Libraries

# %%
# Modelling Libraries
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
# NLP Libraries
import nltk
nltk.download('punkt')
nltk.download("wordnet")
from nltk.stem import WordNetLemmatizer
# Utility Libraries
import pandas as pd
import random
import numpy as np
import json
import pickle
from pathlib import Path
import os
import utils
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hlao1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hlao1\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Setup: Project Paths

# %%
ROOT = utils.get_project_root()
INPUT = ROOT / "input" 
CACHE = ROOT / "cache" # directory for saving trained models
print("ROOT: ", os.listdir(ROOT))
print("INPUT: ", os.listdir(INPUT))
print("CACHE: ", os.listdir(CACHE))
# Out:
# ROOT:  ['.git', '.gitattributes', '.gitignore', '.idea', '.ipynb_checkpoints', 'cache', 'docs', 'gui_chatbot.py', 'input', 'model', 'pychatbot', 'README.md', 'README.md~', 'requirements.txt', 'res', 'run-pychatbot.ipynb', 'venv', 'website', '__init__.py', '__pycache__']
# INPUT:  ['dzone-intents.json', 'oos-eval', 'tim-intents.json']
# CACHE:  ['chatbot_model.h5', 'classes.pkl', 'words.pkl']

# %% [markdown]
# ### Setup: Load Data

# %%
lemmatizer = WordNetLemmatizer()
# load data
with open( INPUT / "dzone-intents.json", "r") as fh:
    intents = json.load(fh)

# %% [markdown]
# # Data Preprocessing
# * Tokenization of the sentences
# * Lemmatization of existing words to reduce all the words to their canonical form (same lexeme)
#     Ex. played, plays, playing -> play

# %% [markdown]
# ### Data Preprocessing: Tokenization

# %%
ignore_chars = "! ? , .".split(" ")
# tokenization
def tokenize(intents:dict)->tuple:
    words, classes, documents = [], [], []
    for i in intents["intents"]:
        for p in i["patterns"]:
            word = nltk.word_tokenize(p)
            words.extend(word)
            documents.append((word, i['tag']))
            if i['tag'] not in classes:
                classes.append(i['tag'])
    return words, classes, documents

(words, classes, documents ) = tokenize(intents)

# %%
documents[:3]
# Out:
# [(['Hi', 'there'], 'greeting'),
#  (['How', 'are', 'you'], 'greeting'),
#  (['Is', 'anyone', 'there', '?'], 'greeting')]

# %% [markdown]
# ### Data Preprocessing: Lemmatization

# %%
# lemmatization
# tranformation of words into a lemma form such that they can be reduced
# to canonical words
# Ex. play, played, plays, playing --> are all mean play
# Reason: reduce number of total words in the model's vocab
words = [lemmatizer.lemmatize(w.lower()) 
         for w in words if w not in ignore_chars]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
# cache into binary files
with open(CACHE / "words.pkl", "wb") as fh:
    pickle.dump(words, fh)
with open(CACHE/"classes.pkl", "wb") as fh:
    pickle.dump(classes, fh)
print("Set Sizes")
print("Documents:",len(documents))
print("Classes:", len(classes))
print("Words:", len(words))
# Out:
# Set Sizes
# Documents: 47
# Classes: 9
# Words: 87

# %% [markdown]
# # Create Training and Testing Set
# * What are we doing here with the documents and the words?
# * How does the creation of the training dataset work here?
# * Numeric conversion of input patterns into numbers
#     1. Lemmatize words of the pattern
#     2. Create the list of zeroes of the same value of the magnitude of the set of all words to be trained
#     3. Set value to be 1 for indices in the list of zeroes in which the word exists in the pattern
#
#
# * Numeric conversion of the input classes applying same method used in input pattern conversion

# %%
# recall that an item in the documents consists of the word pattern + class
print("Entry:",documents[0]) # entry
print("Word pattern:",documents[0][0]) # word pattern
print("Class:",documents[0][1]) # class
# Out:
# Entry: (['Hi', 'there'], 'greeting')
# Word pattern: ['Hi', 'there']
# Class: greeting

# %%
classes
# Out:
# ['adverse_drug',
#  'blood_pressure',
#  'blood_pressure_search',
#  'goodbye',
#  'greeting',
#  'hospital_search',
#  'options',
#  'pharmacy_search',
#  'thanks']

# %%
x = []
Y_empty = [0]*len(classes) 
# iterate over each entry in documents
for d in documents:
    print("Word pattern", d)
    bag = []
    word_patterns = d[0] # access the word pattern
    # lemmatize the entries in the selected word pattern
    lemma_word_patterns = [lemmatizer.lemmatize(w.lower()) for
                    w in word_patterns]
    print("Lemmatized:", word_patterns)
    if (len(lemma_word_patterns) == len(word_patterns)):
        print("Identified case in which the collection of words were reduced to their core meaning")
    # convert the lemmatized word pattern to a numerical value
    for _ in words:
        bag.append(1) if _ in lemma_word_patterns else bag.append(0)
        
    # create the label for the classes in numeric form
    Y_row = list(Y_empty) 
    # set the activation on the output row
    Y_row[classes.index(d[1])] = 1
    print("Numeric Class:",classes.index(d[1]))
    print("Y_row:",Y_row)
    print()
    x.append([bag, Y_row]) # add to the training set

random.shuffle(x) # not sure if this is necessary? why shuffle the data when we create the training data with all of it and there is no test set
x = np.array(x)
x_train, Y_train = list(x[:,0]), list(x[:,1])
# Out:
# Word pattern (['Hi', 'there'], 'greeting')
# Lemmatized: ['Hi', 'there']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['How', 'are', 'you'], 'greeting')
# Lemmatized: ['How', 'are', 'you']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Is', 'anyone', 'there', '?'], 'greeting')
# Lemmatized: ['Is', 'anyone', 'there', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Hey'], 'greeting')
# Lemmatized: ['Hey']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Hola'], 'greeting')
# Lemmatized: ['Hola']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Hello'], 'greeting')
# Lemmatized: ['Hello']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Good', 'day'], 'greeting')
# Lemmatized: ['Good', 'day']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 4
# Y_row: [0, 0, 0, 0, 1, 0, 0, 0, 0]
#
# Word pattern (['Bye'], 'goodbye')
# Lemmatized: ['Bye']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 3
# Y_row: [0, 0, 0, 1, 0, 0, 0, 0, 0]
#
# Word pattern (['See', 'you', 'later'], 'goodbye')
# Lemmatized: ['See', 'you', 'later']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 3
# Y_row: [0, 0, 0, 1, 0, 0, 0, 0, 0]
#
# Word pattern (['Goodbye'], 'goodbye')
# Lemmatized: ['Goodbye']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 3
# Y_row: [0, 0, 0, 1, 0, 0, 0, 0, 0]
#
# Word pattern (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye')
# Lemmatized: ['Nice', 'chatting', 'to', 'you', ',', 'bye']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 3
# Y_row: [0, 0, 0, 1, 0, 0, 0, 0, 0]
#
# Word pattern (['Till', 'next', 'time'], 'goodbye')
# Lemmatized: ['Till', 'next', 'time']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 3
# Y_row: [0, 0, 0, 1, 0, 0, 0, 0, 0]
#
# Word pattern (['Thanks'], 'thanks')
# Lemmatized: ['Thanks']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 8
# Y_row: [0, 0, 0, 0, 0, 0, 0, 0, 1]
#
# Word pattern (['Thank', 'you'], 'thanks')
# Lemmatized: ['Thank', 'you']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 8
# Y_row: [0, 0, 0, 0, 0, 0, 0, 0, 1]
#
# Word pattern (['That', "'s", 'helpful'], 'thanks')
# Lemmatized: ['That', "'s", 'helpful']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 8
# Y_row: [0, 0, 0, 0, 0, 0, 0, 0, 1]
#
# Word pattern (['Awesome', ',', 'thanks'], 'thanks')
# Lemmatized: ['Awesome', ',', 'thanks']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 8
# Y_row: [0, 0, 0, 0, 0, 0, 0, 0, 1]
#
# Word pattern (['Thanks', 'for', 'helping', 'me'], 'thanks')
# Lemmatized: ['Thanks', 'for', 'helping', 'me']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 8
# Y_row: [0, 0, 0, 0, 0, 0, 0, 0, 1]
#
# Word pattern (['How', 'you', 'could', 'help', 'me', '?'], 'options')
# Lemmatized: ['How', 'you', 'could', 'help', 'me', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 6
# Y_row: [0, 0, 0, 0, 0, 0, 1, 0, 0]
#
# Word pattern (['What', 'you', 'can', 'do', '?'], 'options')
# Lemmatized: ['What', 'you', 'can', 'do', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 6
# Y_row: [0, 0, 0, 0, 0, 0, 1, 0, 0]
#
# Word pattern (['What', 'help', 'you', 'provide', '?'], 'options')
# Lemmatized: ['What', 'help', 'you', 'provide', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 6
# Y_row: [0, 0, 0, 0, 0, 0, 1, 0, 0]
#
# Word pattern (['How', 'you', 'can', 'be', 'helpful', '?'], 'options')
# Lemmatized: ['How', 'you', 'can', 'be', 'helpful', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 6
# Y_row: [0, 0, 0, 0, 0, 0, 1, 0, 0]
#
# Word pattern (['What', 'support', 'is', 'offered'], 'options')
# Lemmatized: ['What', 'support', 'is', 'offered']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 6
# Y_row: [0, 0, 0, 0, 0, 0, 1, 0, 0]
#
# Word pattern (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug')
# Lemmatized: ['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 0
# Y_row: [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug')
# Lemmatized: ['Open', 'adverse', 'drugs', 'module']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 0
# Y_row: [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug')
# Lemmatized: ['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 0
# Y_row: [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug')
# Lemmatized: ['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 0
# Y_row: [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug')
# Lemmatized: ['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 0
# Y_row: [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Open', 'blood', 'pressure', 'module'], 'blood_pressure')
# Lemmatized: ['Open', 'blood', 'pressure', 'module']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 1
# Y_row: [0, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure')
# Lemmatized: ['Task', 'related', 'to', 'blood', 'pressure']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 1
# Y_row: [0, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure')
# Lemmatized: ['Blood', 'pressure', 'data', 'entry']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 1
# Y_row: [0, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure')
# Lemmatized: ['I', 'want', 'to', 'log', 'blood', 'pressure', 'results']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 1
# Y_row: [0, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Blood', 'pressure', 'data', 'management'], 'blood_pressure')
# Lemmatized: ['Blood', 'pressure', 'data', 'management']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 1
# Y_row: [0, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search')
# Lemmatized: ['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 2
# Y_row: [0, 0, 1, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search')
# Lemmatized: ['Blood', 'pressure', 'for', 'patient']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 2
# Y_row: [0, 0, 1, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search')
# Lemmatized: ['Load', 'patient', 'blood', 'pressure', 'result']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 2
# Y_row: [0, 0, 1, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search')
# Lemmatized: ['Show', 'blood', 'pressure', 'results', 'for', 'patient']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 2
# Y_row: [0, 0, 1, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search')
# Lemmatized: ['Find', 'blood', 'pressure', 'results', 'by', 'ID']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 2
# Y_row: [0, 0, 1, 0, 0, 0, 0, 0, 0]
#
# Word pattern (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search')
# Lemmatized: ['Find', 'me', 'a', 'pharmacy']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 7
# Y_row: [0, 0, 0, 0, 0, 0, 0, 1, 0]
#
# Word pattern (['Find', 'pharmacy'], 'pharmacy_search')
# Lemmatized: ['Find', 'pharmacy']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 7
# Y_row: [0, 0, 0, 0, 0, 0, 0, 1, 0]
#
# Word pattern (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search')
# Lemmatized: ['List', 'of', 'pharmacies', 'nearby']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 7
# Y_row: [0, 0, 0, 0, 0, 0, 0, 1, 0]
#
# Word pattern (['Locate', 'pharmacy'], 'pharmacy_search')
# Lemmatized: ['Locate', 'pharmacy']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 7
# Y_row: [0, 0, 0, 0, 0, 0, 0, 1, 0]
#
# Word pattern (['Search', 'pharmacy'], 'pharmacy_search')
# Lemmatized: ['Search', 'pharmacy']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 7
# Y_row: [0, 0, 0, 0, 0, 0, 0, 1, 0]
#
# Word pattern (['Lookup', 'for', 'hospital'], 'hospital_search')
# Lemmatized: ['Lookup', 'for', 'hospital']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 5
# Y_row: [0, 0, 0, 0, 0, 1, 0, 0, 0]
#
# Word pattern (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search')
# Lemmatized: ['Searching', 'for', 'hospital', 'to', 'transfer', 'patient']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 5
# Y_row: [0, 0, 0, 0, 0, 1, 0, 0, 0]
#
# Word pattern (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search')
# Lemmatized: ['I', 'want', 'to', 'search', 'hospital', 'data']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 5
# Y_row: [0, 0, 0, 0, 0, 1, 0, 0, 0]
#
# Word pattern (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search')
# Lemmatized: ['Hospital', 'lookup', 'for', 'patient']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 5
# Y_row: [0, 0, 0, 0, 0, 1, 0, 0, 0]
#
# Word pattern (['Looking', 'up', 'hospital', 'details'], 'hospital_search')
# Lemmatized: ['Looking', 'up', 'hospital', 'details']
# Identified case in which the collection of words were reduced to their core meaning
# Numeric Class: 5
# Y_row: [0, 0, 0, 0, 0, 1, 0, 0, 0]
# <ipython-input-9-109e70efd6cc>:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x = np.array(x)

# %%
df_x_train  = pd.DataFrame(x_train)
print("Training input shape:",df_x_train.shape)
# x_train
# Out:
# Training input shape: (47, 87)

# %%
df_Y_train = pd.DataFrame(Y_train)
print("Training output shape",df_Y_train.shape)
# Y_train
# Out:
# Training output shape (47, 9)

# %% [markdown]
# Recall when the intents were loaded, that the size of documents was 47.
# The value of 47 represents the number of instances that are used to train the model.
# The value 87 is the number of features in the dataset ie the number of unique words that occur.
# 9 is the number of classifcations for the entire dataset.

# %% [markdown]
# # Create the Model
# * https://keras.io/guides/sequential_model/
# * https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
#
#
# ### Sequential Model
# * <b>When to use:</b>
#     - nice for a <b>plain stack of layers</b> ie each layer has <b>exactly one input tensor and one output tensor</b>
# * <b>When NOT to use:</b>
#     - model has multiple inputs and/or multiple outputs
#     - any of layers has multiple inputs and/or multiple outputs
#     - need layer sharing
#     - want non-linear topology (ie a residual connection, a multi-branch model)
#
#
# ### Tensor
# * Link to <a href="Tensor Basics with Numpy.ipynb">Tensors Basics Notebook</a>
# <img src="res/n-order-tensor.jpeg" width=250><br>
# ### Perceptron
#
# ### Layer (Dense)
#
#
# ### Rectified Linear Activation Function (ReLU) & Softmax
# * https://machinelearningmastery.com/rectified-linear-activation-function-for-deep-learning-neural-networks/
# * https://machinelearningmastery.com/softmax-activation-function-with-python/
# * https://deepai.org/machine-learning-glossary-and-terms/softmax-layer
# * Why softmax for the output activation?
# * Why ReLU for the input activation?
#
# ### Stochastic Gradient Descent (SGD)

# %%
# use a deep neural network model
model = Sequential()
# add the 1st layer -- an input layer
model.add(Dense(128, input_shape=(len(x_train[0]),), activation='relu'))
model.add(Dropout(0.5))
# add the 2nd layer -- a hidden layer?
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
# add the 3rd layer -- an output layer
model.add(Dense(len(Y_train[0]), activation='softmax'))
# compile the model. SGD + Nesterov accel gradient yields good results 
# for the particular model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])
print("Completed model compilation...")
# train model
hist = model.fit(np.array(x_train), 
                 np.array(Y_train),
                 epochs=200, 
                 batch_size=5,
                 verbose=1)
print("Completed model fitting...")
# cache model state into binary
model.save(CACHE/ "chatbot_model.h5", hist)
print("Completed model caching...")
# Out:
# Completed model compilation...
# Epoch 1/200
# 10/10 [==============================] - 1s 2ms/step - loss: 2.3028 - accuracy: 0.0516
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1821 - accuracy: 0.1353
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1588 - accuracy: 0.2715
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0668 - accuracy: 0.2989
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9589 - accuracy: 0.2991
# Epoch 6/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8972 - accuracy: 0.3865
# Epoch 7/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7380 - accuracy: 0.4573
# Epoch 8/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6209 - accuracy: 0.6250
# Epoch 9/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5813 - accuracy: 0.4883
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3719 - accuracy: 0.6457
# Epoch 11/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3731 - accuracy: 0.6022
# Epoch 12/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2537 - accuracy: 0.6328
# Epoch 13/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9363 - accuracy: 0.7573
# Epoch 14/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0100 - accuracy: 0.7463
# Epoch 15/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7192 - accuracy: 0.8281
# Epoch 16/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7582 - accuracy: 0.7788
# Epoch 17/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4653 - accuracy: 0.9355
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.8527
# Epoch 19/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6108 - accuracy: 0.8351
# Epoch 20/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7239 - accuracy: 0.7257
# Epoch 21/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.8591
# Epoch 22/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.9299
# Epoch 23/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2747 - accuracy: 0.9461
# Epoch 24/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.8332
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3670 - accuracy: 0.9241
# Epoch 26/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3672 - accuracy: 0.9472
# Epoch 27/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1671 - accuracy: 0.9811
# Epoch 28/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.9862
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1518 - accuracy: 0.9826
# Epoch 30/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.9273
# Epoch 31/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2236 - accuracy: 0.9364
# Epoch 32/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2452 - accuracy: 0.9191
# Epoch 33/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1168 - accuracy: 0.9642
# Epoch 34/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2924 - accuracy: 0.9273
# Epoch 35/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2024 - accuracy: 0.9742
# Epoch 36/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.9742
# Epoch 37/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.9558
# Epoch 38/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9052
# Epoch 39/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0655 - accuracy: 0.9892
# Epoch 40/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9661
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1864 - accuracy: 0.9659
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2110 - accuracy: 0.9423
# Epoch 43/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9826
# Epoch 44/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9447
# Epoch 45/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9961
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9273
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9447
# Epoch 48/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.9227
# Epoch 49/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1606 - accuracy: 0.9414
# Epoch 50/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1372 - accuracy: 0.9661
# Epoch 51/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0965 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9617
# Epoch 53/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0813 - accuracy: 0.9862
# Epoch 54/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.9227
# Epoch 55/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1688 - accuracy: 0.9265
# Epoch 57/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0735 - accuracy: 0.9826
# Epoch 58/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0756 - accuracy: 0.9918
# Epoch 59/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1202 - accuracy: 0.9720
# Epoch 60/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0514 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1386 - accuracy: 0.9306
# Epoch 66/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 976us/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0482 - accuracy: 0.9892
# Epoch 69/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1279 - accuracy: 0.9392
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0481 - accuracy: 0.9862
# Epoch 72/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9941
# Epoch 74/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0782 - accuracy: 0.9892
# Epoch 75/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9720
# Epoch 76/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0710 - accuracy: 0.9918
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0839 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0574 - accuracy: 0.9826
# Epoch 80/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0689 - accuracy: 0.9941
# Epoch 82/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0606 - accuracy: 0.9447
# Epoch 85/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 0.9892
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1608 - accuracy: 0.9720
# Epoch 88/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 976us/step - loss: 0.1017 - accuracy: 0.9447
# Epoch 91/200
# 10/10 [==============================] - 0s 942us/step - loss: 0.0523 - accuracy: 0.9638
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1546 - accuracy: 0.9447
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9862
# Epoch 95/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9862
# Epoch 99/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0510 - accuracy: 0.9673
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0738 - accuracy: 0.9862
# Epoch 102/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.9892
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9582
# Epoch 107/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0558 - accuracy: 0.9862
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0254 - accuracy: 0.9918
# Epoch 110/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0593 - accuracy: 0.9826
# Epoch 111/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 0.9862
# Epoch 113/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9862
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9780
# Epoch 120/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0597 - accuracy: 0.9699
# Epoch 122/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 994us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1117 - accuracy: 0.9447
# Epoch 133/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9826
# Epoch 138/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0368 - accuracy: 0.9826
# Epoch 139/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9862
# Epoch 141/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0767 - accuracy: 0.9918
# Epoch 142/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 0.9826
# Epoch 144/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9918
# Epoch 145/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0260 - accuracy: 0.9826
# Epoch 147/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 0.9892
# Epoch 152/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 0.9447
# Epoch 153/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9961
# Epoch 158/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1341 - accuracy: 0.9447
# Epoch 169/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0734 - accuracy: 0.9688
# Epoch 174/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0642 - accuracy: 0.9699
# Epoch 184/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0292 - accuracy: 0.9780
# Epoch 189/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 999us/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 970us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0036 - accuracy: 1.0000
# Completed model fitting...
# Completed model caching...
